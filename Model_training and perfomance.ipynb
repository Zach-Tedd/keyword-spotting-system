# %%
conda install pytorch torchvision torchaudio -c pytorch -c conda-forge
# Out:
# C:\Users\USER\miniconda3\Lib\site-packages\conda\base\context.py:201: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# Channels:
#  - pytorch
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\USER\Desktop\KWS_SYSTEM\env
#
#   added / updated specs:
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libavif_api-1.1.1         |       h57928b3_3          11 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          48 KB  conda-forge
#     aom-3.9.1                  |       he0c23c2_0         1.9 MB  conda-forge
#     ca-certificates-2025.4.26  |       h4c7d964_0         149 KB  conda-forge
#     cairo-1.18.4               |       h5782bbf_0         1.5 MB  conda-forge
#     certifi-2025.4.26          |     pyhd8ed1ab_0         154 KB  conda-forge
#     dav1d-1.2.1                |       hcfcfb64_0         604 KB  conda-forge
#     deprecated-1.2.18          |     pyhd8ed1ab_0          14 KB  conda-forge
#     expat-2.7.0                |       he0c23c2_0         228 KB  conda-forge
#     ffmpeg-6.1.2               | gpl_h63b3451_706         9.1 MB  conda-forge
#     filelock-3.18.0            |     pyhd8ed1ab_0          17 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h765892d_1         188 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.13.3            |       h57928b3_1         180 KB  conda-forge
#     fsspec-2025.3.2            |     pyhd8ed1ab_0         139 KB  conda-forge
#     giflib-5.2.2               |       h64bf75a_0          83 KB  conda-forge
#     glib-2.84.0                |       h3d4babf_0         566 KB  conda-forge
#     glib-tools-2.84.0          |       h4394cf3_0          95 KB  conda-forge
#     graphite2-1.3.13           |    h63175ca_1003          93 KB  conda-forge
#     gst-plugins-base-1.24.7    |       hb0a98b8_0         2.0 MB  conda-forge
#     gstreamer-1.24.7           |       h5006eae_0         1.9 MB  conda-forge
#     harfbuzz-9.0.0             |       h2bedf89_1         1.0 MB  conda-forge
#     icu-75.1                   |       he0c23c2_0        13.9 MB  conda-forge
#     importlib-metadata-8.6.1   |     pyha770c72_0          28 KB  conda-forge
#     krb5-1.21.3                |       hdf4eb48_0         695 KB  conda-forge
#     lcms2-2.17                 |       hbcf6048_0         499 KB  conda-forge
#     libabseil-20250127.0       | cxx17_h4eb7d71_0         1.7 MB  conda-forge
#     libavif16-1.1.1            |       h4d049a7_2          96 KB  conda-forge
#     libclang13-20.1.5          |default_h6e92b77_0        27.0 MB  conda-forge
#     libde265-1.0.15            |       h91493d7_0         247 KB  conda-forge
#     libexpat-2.7.0             |       he0c23c2_0         138 KB  conda-forge
#     libfreetype-2.13.3         |       h57928b3_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h0b5ce68_1         329 KB  conda-forge
#     libgcc-15.1.0              |       h1383e82_2         658 KB  conda-forge
#     libglib-2.84.0             |       h7025463_0         3.7 MB  conda-forge
#     libgomp-15.1.0             |       h1383e82_2         528 KB  conda-forge
#     libheif-1.19.6             | gpl_h2684147_100         383 KB  conda-forge
#     libiconv-1.18              |       h135ad9c_1         623 KB  conda-forge
#     libintl-0.22.5             |       h5728263_3          93 KB  conda-forge
#     libintl-devel-0.22.5       |       h5728263_3          40 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       h2466b09_0         819 KB  conda-forge
#     liblzma-5.8.1              |       h2466b09_1         102 KB  conda-forge
#     liblzma-devel-5.8.1        |       h2466b09_1         126 KB  conda-forge
#     libogg-1.3.5               |       h2466b09_1          34 KB  conda-forge
#     libopus-1.5.2              |       h2466b09_0         282 KB  conda-forge
#     libpng-1.6.47              |       h7a4582a_0         338 KB  conda-forge
#     libpq-17.5                 |       h9087029_0         3.6 MB  conda-forge
#     libprotobuf-5.29.3         |       he9d8c4a_0         6.5 MB  conda-forge
#     libsqlite-3.49.2           |       h67fdade_0         1.0 MB  conda-forge
#     libtiff-4.7.0              |       hdefb170_2         957 KB  conda-forge
#     libtorch-2.5.1             |cpu_mkl_h9002858_104        35.7 MB
#     libuv-1.50.0               |       h2466b09_0         285 KB  conda-forge
#     libvorbis-1.3.7            |       h0e60522_0         267 KB  conda-forge
#     libwebp-base-1.5.0         |       h3b0e114_0         267 KB  conda-forge
#     libwinpthread-12.0.0.r4.gg4f2fc60ca|       h57928b3_9          35 KB  conda-forge
#     libxcb-1.17.0              |       h0e4246c_0         1.2 MB  conda-forge
#     libxml2-2.13.8             |       h442d1da_0         1.4 MB  conda-forge
#     libzlib-1.3.1              |       h2466b09_2          54 KB  conda-forge
#     mpmath-1.3.0               |     pyhd8ed1ab_1         429 KB  conda-forge
#     networkx-3.4.2             |     pyh267e887_2         1.2 MB  conda-forge
#     openh264-2.4.1             |       h63175ca_0         400 KB  conda-forge
#     openssl-3.5.0              |       ha4e3fda_1         8.6 MB  conda-forge
#     opentelemetry-api-1.33.1   |     pyhd8ed1ab_0          45 KB  conda-forge
#     pcre2-10.44                |       h99c9b8b_2         798 KB  conda-forge
#     pillow-11.0.0              |  py313h7b9d4ca_0        40.5 MB  conda-forge
#     pixman-0.46.0              |       had0cd8c_0         462 KB  conda-forge
#     pthread-stubs-0.4          |    h0e40799_1002           9 KB  conda-forge
#     pyqt-5.15.11               |  py313hbdd460c_0         3.7 MB  conda-forge
#     pyqt5-sip-12.17.0          |  py313h5813708_0          74 KB  conda-forge
#     python-3.13.2              |h261c0b1_101_cp313        16.1 MB  conda-forge
#     pytorch-2.5.1              |cpu_mkl_py313h0452e45_104        28.4 MB
#     qt-main-5.15.15            |       h9151539_3        57.1 MB  conda-forge
#     rav1e-0.6.6                |       h975169c_2         1.5 MB  conda-forge
#     sleef-3.8                  |       h7e360cc_0         2.0 MB  conda-forge
#     svt-av1-2.3.0              |       he0c23c2_0         1.8 MB  conda-forge
#     sympy-1.14.0               |     pyh04b8f61_5         4.4 MB  conda-forge
#     tk-8.6.13                  |       h5226925_1         3.3 MB  conda-forge
#     toml-0.10.2                |     pyhd8ed1ab_1          22 KB  conda-forge
#     torchaudio-2.5.1           |  py313hce38976_0         4.9 MB
#     torchvision-0.20.1         |cpu_py313_h8251cf3_6         1.3 MB  conda-forge
#     ucrt-10.0.22621.0          |       h57928b3_1         547 KB  conda-forge
#     vc14_runtime-14.42.34438   |      hfd919c2_26         733 KB  conda-forge
#     vs2015_runtime-14.42.34438 |      h7142326_26          17 KB  conda-forge
#     wrapt-1.17.2               |  py313ha7868ed_0          61 KB  conda-forge
#     x264-1!164.3095            |       h8ffe710_2        1017 KB  conda-forge
#     x265-3.5                   |       h2d74725_3         5.3 MB  conda-forge
#     xorg-libxau-1.0.12         |       h0e40799_0         105 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       h0e40799_0          68 KB  conda-forge
#     xz-5.8.1                   |       h208afaa_1          24 KB  conda-forge
#     xz-tools-5.8.1             |       h2466b09_1          65 KB  conda-forge
#     zipp-3.21.0                |     pyhd8ed1ab_1          21 KB  conda-forge
#     zlib-1.3.1                 |       h2466b09_2         105 KB  conda-forge
#     zstd-1.5.7                 |       hbeecb71_2         346 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       311.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libavif_api       conda-forge/win-64::_libavif_api-1.1.1-h57928b3_3
#   _openmp_mutex      conda-forge/win-64::_openmp_mutex-4.5-2_gnu
#   aom                conda-forge/win-64::aom-3.9.1-he0c23c2_0
#   cairo              conda-forge/win-64::cairo-1.18.4-h5782bbf_0
#   dav1d              conda-forge/win-64::dav1d-1.2.1-hcfcfb64_0
#   deprecated         conda-forge/noarch::deprecated-1.2.18-pyhd8ed1ab_0
#   ffmpeg             conda-forge/win-64::ffmpeg-6.1.2-gpl_h63b3451_706
#   filelock           conda-forge/noarch::filelock-3.18.0-pyhd8ed1ab_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/win-64::fontconfig-2.15.0-h765892d_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fsspec             conda-forge/noarch::fsspec-2025.3.2-pyhd8ed1ab_0
#   giflib             conda-forge/win-64::giflib-5.2.2-h64bf75a_0
#   glib               conda-forge/win-64::glib-2.84.0-h3d4babf_0
#   glib-tools         conda-forge/win-64::glib-tools-2.84.0-h4394cf3_0
#   graphite2          conda-forge/win-64::graphite2-1.3.13-h63175ca_1003
#   gst-plugins-base   conda-forge/win-64::gst-plugins-base-1.24.7-hb0a98b8_0
#   gstreamer          conda-forge/win-64::gstreamer-1.24.7-h5006eae_0
#   harfbuzz           conda-forge/win-64::harfbuzz-9.0.0-h2bedf89_1
#   importlib-metadata conda-forge/noarch::importlib-metadata-8.6.1-pyha770c72_0
#   libabseil          conda-forge/win-64::libabseil-20250127.0-cxx17_h4eb7d71_0
#   libavif16          conda-forge/win-64::libavif16-1.1.1-h4d049a7_2
#   libclang13         conda-forge/win-64::libclang13-20.1.5-default_h6e92b77_0
#   libde265           conda-forge/win-64::libde265-1.0.15-h91493d7_0
#   libexpat           conda-forge/win-64::libexpat-2.7.0-he0c23c2_0
#   libfreetype        conda-forge/win-64::libfreetype-2.13.3-h57928b3_1
#   libfreetype6       conda-forge/win-64::libfreetype6-2.13.3-h0b5ce68_1
#   libgcc             conda-forge/win-64::libgcc-15.1.0-h1383e82_2
#   libglib            conda-forge/win-64::libglib-2.84.0-h7025463_0
#   libgomp            conda-forge/win-64::libgomp-15.1.0-h1383e82_2
#   libheif            conda-forge/win-64::libheif-1.19.6-gpl_h2684147_100
#   libiconv           conda-forge/win-64::libiconv-1.18-h135ad9c_1
#   libintl            conda-forge/win-64::libintl-0.22.5-h5728263_3
#   libintl-devel      conda-forge/win-64::libintl-devel-0.22.5-h5728263_3
#   libjpeg-turbo      conda-forge/win-64::libjpeg-turbo-3.1.0-h2466b09_0
#   liblzma            conda-forge/win-64::liblzma-5.8.1-h2466b09_1
#   liblzma-devel      conda-forge/win-64::liblzma-devel-5.8.1-h2466b09_1
#   libogg             conda-forge/win-64::libogg-1.3.5-h2466b09_1
#   libopus            conda-forge/win-64::libopus-1.5.2-h2466b09_0
#   libprotobuf        conda-forge/win-64::libprotobuf-5.29.3-he9d8c4a_0
#   libsqlite          conda-forge/win-64::libsqlite-3.49.2-h67fdade_0
#   libtorch           pkgs/main/win-64::libtorch-2.5.1-cpu_mkl_h9002858_104
#   libuv              conda-forge/win-64::libuv-1.50.0-h2466b09_0
#   libvorbis          conda-forge/win-64::libvorbis-1.3.7-h0e60522_0
#   libwinpthread      conda-forge/win-64::libwinpthread-12.0.0.r4.gg4f2fc60ca-h57928b3_9
#   libxcb             conda-forge/win-64::libxcb-1.17.0-h0e4246c_0
#   libxml2            conda-forge/win-64::libxml2-2.13.8-h442d1da_0
#   libzlib            conda-forge/win-64::libzlib-1.3.1-h2466b09_2
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_1
#   networkx           conda-forge/noarch::networkx-3.4.2-pyh267e887_2
#   openh264           conda-forge/win-64::openh264-2.4.1-h63175ca_0
#   opentelemetry-api  conda-forge/noarch::opentelemetry-api-1.33.1-pyhd8ed1ab_0
#   pcre2              conda-forge/win-64::pcre2-10.44-h99c9b8b_2
#   pixman             conda-forge/win-64::pixman-0.46.0-had0cd8c_0
#   pthread-stubs      conda-forge/win-64::pthread-stubs-0.4-h0e40799_1002
#   pyqt5-sip          conda-forge/win-64::pyqt5-sip-12.17.0-py313h5813708_0
#   pytorch            pkgs/main/win-64::pytorch-2.5.1-cpu_mkl_py313h0452e45_104
#   qt-main            conda-forge/win-64::qt-main-5.15.15-h9151539_3
#   rav1e              conda-forge/win-64::rav1e-0.6.6-h975169c_2
#   sleef              conda-forge/win-64::sleef-3.8-h7e360cc_0
#   svt-av1            conda-forge/win-64::svt-av1-2.3.0-he0c23c2_0
#   sympy              conda-forge/noarch::sympy-1.14.0-pyh04b8f61_5
#   toml               conda-forge/noarch::toml-0.10.2-pyhd8ed1ab_1
#   torchaudio         pkgs/main/win-64::torchaudio-2.5.1-py313hce38976_0
#   torchvision        conda-forge/win-64::torchvision-0.20.1-cpu_py313_h8251cf3_6
#   ucrt               conda-forge/win-64::ucrt-10.0.22621.0-h57928b3_1
#   vc14_runtime       conda-forge/win-64::vc14_runtime-14.42.34438-hfd919c2_26
#   wrapt              conda-forge/win-64::wrapt-1.17.2-py313ha7868ed_0
#   x264               conda-forge/win-64::x264-1!164.3095-h8ffe710_2
#   x265               conda-forge/win-64::x265-3.5-h2d74725_3
#   xorg-libxau        conda-forge/win-64::xorg-libxau-1.0.12-h0e40799_0
#   xorg-libxdmcp      conda-forge/win-64::xorg-libxdmcp-1.1.5-h0e40799_0
#   xz-tools           conda-forge/win-64::xz-tools-5.8.1-h2466b09_1
#   zipp               conda-forge/noarch::zipp-3.21.0-pyhd8ed1ab_1
#
# The following packages will be REMOVED:
#
#   jpeg-9e-h827c3e9_3
#   qtbase-6.7.3-h0804d20_0
#   qtdeclarative-6.7.3-h5da7b33_0
#   qtsvg-6.7.3-hf2fb9eb_0
#   qttools-6.7.3-h0de5f00_0
#   qtwebchannel-6.7.3-h5da7b33_0
#   qtwebsockets-6.7.3-h5da7b33_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/win-64::ca-certificates-202~ --> conda-forge/noarch::ca-certificates-2025.4.26-h4c7d964_0
#   freetype            pkgs/main::freetype-2.13.3-h0620614_0 --> conda-forge::freetype-2.13.3-h57928b3_1
#   icu                        pkgs/main::icu-73.1-h6c2663c_0 --> conda-forge::icu-75.1-he0c23c2_0
#   krb5                    pkgs/main::krb5-1.20.1-h5b6d351_0 --> conda-forge::krb5-1.21.3-hdf4eb48_0
#   lcms2                    pkgs/main::lcms2-2.16-h62be587_1 --> conda-forge::lcms2-2.17-hbcf6048_0
#   libpng                pkgs/main::libpng-1.6.39-h8cc25b3_0 --> conda-forge::libpng-1.6.47-h7a4582a_0
#   libpq                    pkgs/main::libpq-17.4-h70ee33d_0 --> conda-forge::libpq-17.5-h9087029_0
#   libtiff               pkgs/main::libtiff-4.7.0-h404307b_0 --> conda-forge::libtiff-4.7.0-hdefb170_2
#   libwebp-base       pkgs/main::libwebp-base-1.3.2-h3d0472~ --> conda-forge::libwebp-base-1.5.0-h3b0e114_0
#   openssl              pkgs/main::openssl-3.0.16-h3f729d1_0 --> conda-forge::openssl-3.5.0-ha4e3fda_1
#   python             pkgs/main::python-3.13.2-hadb2040_100~ --> conda-forge::python-3.13.2-h261c0b1_101_cp313
#   vs2015_runtime     pkgs/main::vs2015_runtime-14.42.34433~ --> conda-forge::vs2015_runtime-14.42.34438-h7142326_26
#   xz                         pkgs/main::xz-5.6.4-h4754444_1 --> conda-forge::xz-5.8.1-h208afaa_1
#   zlib                    pkgs/main::zlib-1.2.13-h8cc25b3_1 --> conda-forge::zlib-1.3.1-h2466b09_2
#   zstd                     pkgs/main::zstd-1.5.6-h8880b57_0 --> conda-forge::zstd-1.5.7-hbeecb71_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/win-64::certifi-2025.4.26-p~ --> conda-forge/noarch::certifi-2025.4.26-pyhd8ed1ab_0
#   expat                   pkgs/main::expat-2.7.1-h8ddb27b_0 --> conda-forge::expat-2.7.0-he0c23c2_0
#   pillow             pkgs/main::pillow-11.1.0-py313hea0d53~ --> conda-forge::pillow-11.0.0-py313h7b9d4ca_0
#   pyqt                pkgs/main::pyqt-6.7.1-py313h5da7b33_1 --> conda-forge::pyqt-5.15.11-py313hbdd460c_0
#   tk                        pkgs/main::tk-8.6.14-h0416ee5_0 --> conda-forge::tk-8.6.13-h5226925_1
#
#
#
# Downloading and Extracting Packages: ...working...
# qt-main-5.15.15      | 57.1 MB   |            |   0%
#
# pillow-11.0.0        | 40.5 MB   |            |   0%
#
#
# libtorch-2.5.1       | 35.7 MB   |            |   0%
#
#
#
# pytorch-2.5.1        | 28.4 MB   |            |   0%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   |            |   0%
#
#
#
#
#
# python-3.13.2        | 16.1 MB   |            |   0%
#
#
#
#
#
#
# icu-75.1             | 13.9 MB   |            |   0%
#
#
#
#
#
#
#
# ffmpeg-6.1.2         | 9.1 MB    |            |   0%
#
#
#
#
#
#
#
#
# openssl-3.5.0        | 8.6 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# libprotobuf-5.29.3   | 6.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# x265-3.5             | 5.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 4.9 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# sympy-1.14.0         | 4.4 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.15.11         | 3.7 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.84.0       | 3.7 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gst-plugins-base-1.2 | 2.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   |            |   0%
# qt-main-5.15.15      | 57.1 MB   | #2         |  12%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   |            |   0%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   |            |   0%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   |            |   1%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   |            |   1%
# qt-main-5.15.15      | 57.1 MB   | #2         |  13%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   |            |   1%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   |            |   1%
# qt-main-5.15.15      | 57.1 MB   | #2         |  13%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   |            |   1%
# qt-main-5.15.15      | 57.1 MB   | #2         |  13%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 1          |   1%
# qt-main-5.15.15      | 57.1 MB   | #3         |  13%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 1          |   1%
# qt-main-5.15.15      | 57.1 MB   | #3         |  13%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 1          |   1%
# qt-main-5.15.15      | 57.1 MB   | #3         |  13%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 1          |   1%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###5       |  36%
# qt-main-5.15.15      | 57.1 MB   | #3         |  13%
#
# pillow-11.0.0        | 40.5 MB   | ####1      |  42%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 1          |   2%
# qt-main-5.15.15      | 57.1 MB   | #3         |  13%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 1          |   2%
# qt-main-5.15.15      | 57.1 MB   | #3         |  13%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 1          |   2%
# qt-main-5.15.15      | 57.1 MB   | #3         |  14%
# qt-main-5.15.15      | 57.1 MB   | #3         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 1          |   2%
# qt-main-5.15.15      | 57.1 MB   | #3         |  14%
# qt-main-5.15.15      | 57.1 MB   | #3         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 1          |   2%
# qt-main-5.15.15      | 57.1 MB   | #3         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   2%
# qt-main-5.15.15      | 57.1 MB   | #3         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   2%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   2%
# qt-main-5.15.15      | 57.1 MB   | #3         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   2%
# qt-main-5.15.15      | 57.1 MB   | #4         |  14%
# qt-main-5.15.15      | 57.1 MB   | #4         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   2%
# qt-main-5.15.15      | 57.1 MB   | #4         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   2%
# qt-main-5.15.15      | 57.1 MB   | #4         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   2%
#
# pillow-11.0.0        | 40.5 MB   | ####2      |  42%
#
#
# libtorch-2.5.1       | 35.7 MB   | ###9       |  40%
# qt-main-5.15.15      | 57.1 MB   | #4         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   3%
# qt-main-5.15.15      | 57.1 MB   | #4         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   3%
# qt-main-5.15.15      | 57.1 MB   | #4         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   3%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   3%
# qt-main-5.15.15      | 57.1 MB   | #4         |  14%
# qt-main-5.15.15      | 57.1 MB   | #4         |  14%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   3%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###6       |  37%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   3%
# qt-main-5.15.15      | 57.1 MB   | #4         |  15%
# qt-main-5.15.15      | 57.1 MB   | #4         |  15%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 2          |   3%
#
# pillow-11.0.0        | 40.5 MB   | ####2      |  43%
# qt-main-5.15.15      | 57.1 MB   | #4         |  15%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   3%
# qt-main-5.15.15      | 57.1 MB   | #4         |  15%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   3%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####       |  40%
# qt-main-5.15.15      | 57.1 MB   | #4         |  15%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   3%
# qt-main-5.15.15      | 57.1 MB   | #4         |  15%
# qt-main-5.15.15      | 57.1 MB   | #4         |  15%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###6       |  37%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   3%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  43%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   3%
# qt-main-5.15.15      | 57.1 MB   | #4         |  15%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   3%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####       |  41%
# qt-main-5.15.15      | 57.1 MB   | #4         |  15%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   3%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  43%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   4%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   4%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###7       |  37%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  43%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   4%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####       |  41%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###7       |  37%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   4%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  44%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###7       |  37%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####       |  41%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 3          |   4%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  44%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####       |  41%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###7       |  37%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   4%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   4%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   4%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###7       |  38%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  41%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  44%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###7       |  38%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   4%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  44%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###7       |  38%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   4%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  41%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   4%
#
# pillow-11.0.0        | 40.5 MB   | ####3      |  44%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###7       |  38%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   4%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  41%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  44%
# qt-main-5.15.15      | 57.1 MB   | #5         |  15%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###7       |  38%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  44%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  41%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   5%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  41%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   5%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  38%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  41%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   5%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  41%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  44%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  44%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  38%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  41%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   5%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  42%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   5%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  38%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   5%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  44%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  38%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  42%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 4          |   5%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  44%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  42%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  39%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   5%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  42%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  39%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   5%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  39%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  42%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  39%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####1      |  42%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   5%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   5%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  39%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   5%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   5%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  39%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
# qt-main-5.15.15      | 57.1 MB   | #5         |  16%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###8       |  39%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   5%
# qt-main-5.15.15      | 57.1 MB   | #6         |  16%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   6%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  39%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
# qt-main-5.15.15      | 57.1 MB   | #6         |  16%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  39%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   6%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
# qt-main-5.15.15      | 57.1 MB   | #6         |  16%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   6%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  39%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
# qt-main-5.15.15      | 57.1 MB   | #6         |  16%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  39%
#
# pillow-11.0.0        | 40.5 MB   | ####4      |  45%
# qt-main-5.15.15      | 57.1 MB   | #6         |  16%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   6%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  39%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
# qt-main-5.15.15      | 57.1 MB   | #6         |  16%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  42%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 5          |   6%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  39%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
# qt-main-5.15.15      | 57.1 MB   | #6         |  16%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  39%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   6%
# qt-main-5.15.15      | 57.1 MB   | #6         |  16%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  40%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   6%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  43%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   6%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  40%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   6%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  43%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  40%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  43%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   6%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  40%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   6%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ###9       |  40%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  43%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   6%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####       |  40%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  43%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   6%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####       |  40%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####2      |  43%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   7%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####       |  40%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   7%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  45%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####       |  40%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   7%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   7%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  46%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####       |  41%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   7%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####       |  41%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  46%
# qt-main-5.15.15      | 57.1 MB   | #6         |  17%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   7%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####       |  41%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   7%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  46%
# qt-main-5.15.15      | 57.1 MB   | #7         |  17%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####       |  41%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 6          |   7%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  46%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
# qt-main-5.15.15      | 57.1 MB   | #7         |  17%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####       |  41%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  46%
# qt-main-5.15.15      | 57.1 MB   | #7         |  17%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   7%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  46%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   7%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  41%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
# qt-main-5.15.15      | 57.1 MB   | #7         |  17%
#
# pillow-11.0.0        | 40.5 MB   | ####5      |  46%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   7%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  41%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  46%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   7%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  43%
# qt-main-5.15.15      | 57.1 MB   | #7         |  17%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  41%
# qt-main-5.15.15      | 57.1 MB   | #7         |  17%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   7%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  46%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  44%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  41%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  41%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   7%
# qt-main-5.15.15      | 57.1 MB   | #7         |  17%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  44%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  46%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  41%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  46%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   7%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  41%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  46%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  44%
# qt-main-5.15.15      | 57.1 MB   | #7         |  17%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   8%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  42%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  44%
# qt-main-5.15.15      | 57.1 MB   | #7         |  17%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  46%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   8%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  42%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  44%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  46%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   8%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  44%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  42%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  46%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   8%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  42%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  44%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  46%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   8%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####1      |  42%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####3      |  44%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   8%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  47%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   8%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####2      |  42%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  47%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####2      |  42%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   8%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  47%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####2      |  42%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  47%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 7          |   8%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  47%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####2      |  42%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   8%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####2      |  42%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  47%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   8%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  47%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####2      |  43%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   8%
#
# pillow-11.0.0        | 40.5 MB   | ####6      |  47%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
# qt-main-5.15.15      | 57.1 MB   | #7         |  18%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   8%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  47%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   8%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####2      |  43%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  47%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   8%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  44%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####2      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  47%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   8%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  45%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  47%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####2      |  43%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   8%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  47%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  45%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   8%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####2      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  47%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  45%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  47%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   9%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  45%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   9%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  45%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  43%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   9%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  47%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  43%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  45%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  47%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  43%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   9%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  45%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  43%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   9%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  45%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  48%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  48%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  45%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   9%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  43%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  48%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   9%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  44%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####4      |  45%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 8          |   9%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  48%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  45%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |   9%
# qt-main-5.15.15      | 57.1 MB   | #8         |  18%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  48%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  45%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  44%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  45%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |   9%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
# pillow-11.0.0        | 40.5 MB   | ####7      |  48%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  44%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  44%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  45%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |   9%
#
# pillow-11.0.0        | 40.5 MB   | ####8      |  48%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####3      |  44%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  45%
#
# pillow-11.0.0        | 40.5 MB   | ####8      |  48%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |   9%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  45%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####4      |  44%
#
# pillow-11.0.0        | 40.5 MB   | ####8      |  48%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####4      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |   9%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  45%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####4      |  44%
#
# pillow-11.0.0        | 40.5 MB   | ####8      |  48%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  45%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |   9%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
# pillow-11.0.0        | 40.5 MB   | ####8      |  48%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####4      |  44%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |   9%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  45%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####4      |  44%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |  10%
#
# pillow-11.0.0        | 40.5 MB   | ####8      |  48%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####4      |  44%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  46%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |  10%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  46%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####4      |  45%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |  10%
#
# pillow-11.0.0        | 40.5 MB   | ####8      |  49%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####4      |  45%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |  10%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
# pillow-11.0.0        | 40.5 MB   | ####8      |  49%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####4      |  45%
#
#
# libtorch-2.5.1       | 35.7 MB   | ####5      |  46%
#
#
#
#
# libclang13-20.1.5    | 27.0 MB   | 9          |  10%
#
# pillow-11.0.0        | 40.5 MB   | ####8      |  49%
# qt-main-5.15.15      | 57.1 MB   | #8         |  19%
#
#
#
# pytorch-2.5.1        | 28.4 MB   | ####4      |  45%
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | ########4  |  84%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######5    |  65%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | ########5  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######5    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ######9    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | ########6  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######6    |  67%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######7    |  67%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######1   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######8    |  68%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | ########8  |  89%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######3   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######9    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########  |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######4   |  75%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########1 |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######1   |  71%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######1   |  72%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######2   |  72%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########3 |  94%
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######8   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######3   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #######9   |  80%
# qt-main-5.15.15      | 57.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########   |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########5 |  95%
# qt-main-5.15.15      | 57.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######4   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######5   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########2  |  82%
# qt-main-5.15.15      | 57.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######6   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########3  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########4  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######9   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########5  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########9 |  99%
# qt-main-5.15.15      | 57.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######9   |  80%
# qt-main-5.15.15      | 57.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########   |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########6  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########1  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########7  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sleef-3.8            | 2.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########2  |  83%
# qt-main-5.15.15      | 57.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########8  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########4  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########9  |  90%
# qt-main-5.15.15      | 57.1 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########5  |  86%
# qt-main-5.15.15      | 57.1 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########6  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########1 |  91%
# qt-main-5.15.15      | 57.1 MB   | #########9 | 100%
# qt-main-5.15.15      | 57.1 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########8  |  88%
# qt-main-5.15.15      | 57.1 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########9  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########1 |  91%
# qt-main-5.15.15      | 57.1 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########3 |  94%
# qt-main-5.15.15      | 57.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpq-17.5           | 3.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.15      | 57.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# 2.5.1
# CUDA available: False

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.metrics import accuracy_score
from tqdm import tqdm
import pandas as pd

# --- Dataset class ---
class KeywordDataset(Dataset):
    def __init__(self, feature_dir, max_len=80):
        self.data = []
        self.labels = []
        self.label_map = {}
        self.max_len = max_len
        idx = 0

        for label in sorted(os.listdir(feature_dir)):
            label_path = os.path.join(feature_dir, label)
            if not os.path.isdir(label_path):
                continue

            if label not in self.label_map:
                self.label_map[label] = idx
                idx += 1

            for file in os.listdir(label_path):
                if file.endswith(".npy"):
                    path = os.path.join(label_path, file)
                    feat = np.load(path)
                    self.data.append(feat.astype(np.float32))
                    self.labels.append(self.label_map[label])

        self.labels = np.array(self.labels)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        x = self.data[idx]
        c, t = x.shape  # (freq, time)
        if t < self.max_len:
            pad = self.max_len - t
            x = np.pad(x, ((0, 0), (0, pad)), mode='constant')
        elif t > self.max_len:
            x = x[:, :self.max_len]
        x = np.expand_dims(x, axis=0)  # (1, freq, time)
        return x, self.labels[idx]

# --- CNN model ---
class SimpleCNN(nn.Module):
    def __init__(self, input_shape=(1, 13, 80), num_classes=10):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2)
        self.dropout = nn.Dropout(0.3)

        # 🔧 Dynamically determine the input size for fc1
        self.flatten_dim = self._get_flatten_size(input_shape)
        self.fc1 = nn.Linear(self.flatten_dim, 128)
        self.fc2 = nn.Linear(128, num_classes)

    def _get_flatten_size(self, shape):
        with torch.no_grad():
            x = torch.zeros(1, *shape)
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            return x.view(1, -1).shape[1]

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = self.dropout(F.relu(self.fc1(x)))
        return self.fc2(x)

# --- Training function ---
def train_and_evaluate(feature_dir, max_len=80, epochs=5):
    dataset = KeywordDataset(feature_dir, max_len=max_len)
    if len(dataset) < 10: return None  # skip empty sets

    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_set, val_set = random_split(dataset, [train_size, val_size])

    train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=32)

   # model = SimpleCNN().to(device)
    #model = SimpleCNN(input_shape=(1, 40, 80)).to(device)
    # Decide input shape based on feature type
    input_shape = (1, 13, 80) if 'mfcc' in feature_type else (1, 40, 80)
    model = SimpleCNN(input_shape=input_shape).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        for xb, yb in train_loader:
           # xb, yb = torch.tensor(xb).to(device), torch.tensor(yb).to(device)
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()

    # Evaluate
    model.eval()
    preds, labels = [], []
    with torch.no_grad():
        for xb, yb in val_loader:
            xb = torch.tensor(xb).to(device)
            out = model(xb)
            preds.extend(torch.argmax(out, axis=1).cpu().numpy())
            labels.extend(yb.numpy())

    return accuracy_score(labels, preds)

# --- Run all configs ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
results = []

for feature_type in ['features_mfcc', 'features_mel']:
    base_path = feature_type
    for win_ms in range(10, 101, 10):
        for overlap in [0, 25, 50, 75]:
            path = f"{base_path}/win_{win_ms}/overlap_{overlap}"
            print(f"Training: {feature_type}, Win={win_ms}ms, Overlap={overlap}%")
            acc = train_and_evaluate(path)
            if acc is not None:
                results.append({
                    "Feature": feature_type.replace("features_", ""),
                    "Window": win_ms,
                    "Overlap": overlap,
                    "Accuracy": round(acc, 4)
                })

# Save results to CSV
df = pd.DataFrame(results)
df.to_csv("results_summary.csv", index=False)
print("\n✅ Evaluation complete. Results saved to results_summary.csv")
# Out:
# Training: features_mfcc, Win=10ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=10ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=10ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=10ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=20ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=20ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=20ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=20ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=30ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=30ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=30ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=30ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=40ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=40ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=40ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=40ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=50ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=50ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=50ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=50ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=60ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=60ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=60ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=60ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=70ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=70ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=70ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=70ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=80ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=80ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=80ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=80ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=90ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=90ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=90ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=90ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=100ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=100ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=100ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mfcc, Win=100ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=10ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=10ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=10ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=10ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=20ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=20ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=20ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=20ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=30ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=30ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=30ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=30ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=40ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=40ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=40ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=40ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=50ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=50ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=50ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=50ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=60ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=60ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=60ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=60ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=70ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=70ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=70ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=70ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=80ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=80ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=80ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=80ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=90ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=90ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=90ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=90ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=100ms, Overlap=0%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=100ms, Overlap=25%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=100ms, Overlap=50%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# Training: features_mel, Win=100ms, Overlap=75%
# C:\Users\USER\AppData\Local\Temp\ipykernel_22656\1042750358.py:116: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xb = torch.tensor(xb).to(device)
# ✅ Evaluation complete. Results saved to results_summary.csv

# %%
torch.save(model.state_dict(), 'best_model.pth')

# %%
print(dataset.label_map)
# Out:
# {'down': 0, 'go': 1, 'left': 2, 'no': 3, 'off': 4, 'on': 5, 'right': 6, 'stop': 7, 'up': 8, 'yes': 9}
